# %% [markdown]
# # {{PROJECT_TITLE}}
#
# **Template only:** add your original analysis. This notebook contains no experimental results.
#
# State the physical question, authorship, and scope.

# %% [markdown]
# ## Inputs and units
#
# Describe the data source, filenames, columns or image format, units, and acquisition conditions.

# %%
# Add your imports and data-loading code here.
# Use paths that work from the documented notebook working directory.

# %% [markdown]
# ## Method and assumptions
#
# Explain the model or numerical method, calibration, and treatment of background or uncertainty.

# %%
# Add the original analysis, fitting, or simulation code here.

# %% [markdown]
# ## Checks
#
# Add a meaningful check appropriate to this analysis: residuals, known inputs, convergence, or comparison with an independent calculation.

# %%
# Add the check and visualization code here.

# %% [markdown]
# ## Results and limitations
#
# Interpret the actual output. State units, uncertainty where supported, limitations, and what you would investigate next.
